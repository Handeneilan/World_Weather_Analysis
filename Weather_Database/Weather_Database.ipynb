# %%
#Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Import the requests library.
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_current = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),                         
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_current,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | beringovskiy
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | bolshaya vishera
# City not found. Skipping...
# Processing Record 6 of Set 1 | wabag
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | san patricio
# Processing Record 9 of Set 1 | north bend
# Processing Record 10 of Set 1 | kewanee
# Processing Record 11 of Set 1 | souillac
# Processing Record 12 of Set 1 | hamilton
# Processing Record 13 of Set 1 | lompoc
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | manavalakurichi
# Processing Record 17 of Set 1 | pedernales
# Processing Record 18 of Set 1 | leningradskiy
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | maragogi
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | korla
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | corn island
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | notre-dame-du-lac
# Processing Record 29 of Set 1 | lata
# Processing Record 30 of Set 1 | yulara
# Processing Record 31 of Set 1 | sitka
# Processing Record 32 of Set 1 | bytow
# Processing Record 33 of Set 1 | coihaique
# Processing Record 34 of Set 1 | tautira
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 1 | berlevag
# Processing Record 41 of Set 1 | calvia
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | nhulunbuy
# Processing Record 44 of Set 1 | fort nelson
# Processing Record 45 of Set 1 | kruisfontein
# Processing Record 46 of Set 1 | whitewater
# Processing Record 47 of Set 1 | port hardy
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 1 | upata
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | castro verde
# Processing Record 3 of Set 2 | nakhon si thammarat
# Processing Record 4 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 2 | chumikan
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | codajas
# Processing Record 8 of Set 2 | beira
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | san andres
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | hasaki
# Processing Record 15 of Set 2 | longyearbyen
# Processing Record 16 of Set 2 | bull savanna
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | coahuayana
# Processing Record 19 of Set 2 | vestmannaeyjar
# Processing Record 20 of Set 2 | ahipara
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | hualmay
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | hajduszovat
# Processing Record 26 of Set 2 | itaituba
# Processing Record 27 of Set 2 | forbes
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 2 | vanavara
# Processing Record 31 of Set 2 | marsabit
# Processing Record 32 of Set 2 | pangody
# Processing Record 33 of Set 2 | khandyga
# Processing Record 34 of Set 2 | enterprise
# Processing Record 35 of Set 2 | changli
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | lavrentiya
# Processing Record 38 of Set 2 | takoradi
# Processing Record 39 of Set 2 | omboue
# Processing Record 40 of Set 2 | de panne
# Processing Record 41 of Set 2 | bridlington
# Processing Record 42 of Set 2 | grindavik
# Processing Record 43 of Set 2 | hofn
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | toulepleu
# City not found. Skipping...
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | hobart
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | luanda
# Processing Record 1 of Set 3 | williams lake
# Processing Record 2 of Set 3 | sochi
# Processing Record 3 of Set 3 | topeka
# Processing Record 4 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 3 | okhotsk
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | qaanaaq
# Processing Record 8 of Set 3 | tabou
# Processing Record 9 of Set 3 | naousa
# Processing Record 10 of Set 3 | la reforma
# Processing Record 11 of Set 3 | puerto del rosario
# Processing Record 12 of Set 3 | kalat
# Processing Record 13 of Set 3 | saint albans
# Processing Record 14 of Set 3 | aklavik
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | nantucket
# Processing Record 17 of Set 3 | saint-augustin
# Processing Record 18 of Set 3 | lima
# Processing Record 19 of Set 3 | vao
# Processing Record 20 of Set 3 | bilma
# Processing Record 21 of Set 3 | deder
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | oranjemund
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | ilulissat
# Processing Record 26 of Set 3 | mahaicony
# City not found. Skipping...
# Processing Record 27 of Set 3 | cherskiy
# Processing Record 28 of Set 3 | alofi
# Processing Record 29 of Set 3 | kendari
# Processing Record 30 of Set 3 | hihya
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | kavieng
# Processing Record 34 of Set 3 | klaksvik
# Processing Record 35 of Set 3 | antsohihy
# Processing Record 36 of Set 3 | kidal
# Processing Record 37 of Set 3 | luderitz
# Processing Record 38 of Set 3 | bambous virieux
# Processing Record 39 of Set 3 | domoni
# Processing Record 40 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 3 | asau
# Processing Record 42 of Set 3 | torbay
# Processing Record 43 of Set 3 | vostok
# Processing Record 44 of Set 3 | mahebourg
# Processing Record 45 of Set 3 | georgetown
# Processing Record 46 of Set 3 | maceio
# Processing Record 47 of Set 3 | marzuq
# Processing Record 48 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 3 | fortuna
# Processing Record 50 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 1 of Set 4 | hermanus
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | sioux lookout
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | coquimbo
# Processing Record 6 of Set 4 | mount gambier
# Processing Record 7 of Set 4 | narsaq
# Processing Record 8 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 4 | pontianak
# Processing Record 10 of Set 4 | pitimbu
# Processing Record 11 of Set 4 | hervey bay
# Processing Record 12 of Set 4 | kodiak
# Processing Record 13 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 4 | verkhoturye
# Processing Record 15 of Set 4 | guru har sahai
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | mount isa
# Processing Record 18 of Set 4 | abong mbang
# Processing Record 19 of Set 4 | cabra
# Processing Record 20 of Set 4 | solnechnyy
# Processing Record 21 of Set 4 | were ilu
# Processing Record 22 of Set 4 | kropotkin
# Processing Record 23 of Set 4 | vorontsovka
# Processing Record 24 of Set 4 | tessalit
# Processing Record 25 of Set 4 | saint-louis
# Processing Record 26 of Set 4 | reconquista
# Processing Record 27 of Set 4 | koumac
# Processing Record 28 of Set 4 | severomuysk
# Processing Record 29 of Set 4 | tukrah
# Processing Record 30 of Set 4 | yumen
# Processing Record 31 of Set 4 | dingle
# Processing Record 32 of Set 4 | lebanon
# Processing Record 33 of Set 4 | vicente guerrero
# Processing Record 34 of Set 4 | mayari
# City not found. Skipping...
# Processing Record 35 of Set 4 | vung tau
# Processing Record 36 of Set 4 | luau
# Processing Record 37 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 4 | ponca city
# Processing Record 39 of Set 4 | raudeberg
# Processing Record 40 of Set 4 | bilibino
# Processing Record 41 of Set 4 | vanimo
# Processing Record 42 of Set 4 | kholuy
# Processing Record 43 of Set 4 | shumyachi
# Processing Record 44 of Set 4 | dunedin
# Processing Record 45 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 4 | kralendijk
# Processing Record 47 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 48 of Set 4 | karratha
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | lagoa
# Processing Record 1 of Set 5 | alvorada
# Processing Record 2 of Set 5 | aksu
# Processing Record 3 of Set 5 | porosozero
# Processing Record 4 of Set 5 | ouargaye
# Processing Record 5 of Set 5 | tuatapere
# Processing Record 6 of Set 5 | taloqan
# Processing Record 7 of Set 5 | broken hill
# Processing Record 8 of Set 5 | tawau
# Processing Record 9 of Set 5 | byron bay
# Processing Record 10 of Set 5 | olafsvik
# Processing Record 11 of Set 5 | nanortalik
# Processing Record 12 of Set 5 | hovd
# Processing Record 13 of Set 5 | namibe
# Processing Record 14 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 15 of Set 5 | alice springs
# Processing Record 16 of Set 5 | zhaoqing
# Processing Record 17 of Set 5 | bloemfontein
# Processing Record 18 of Set 5 | krasnyye baki
# Processing Record 19 of Set 5 | lac du bonnet
# Processing Record 20 of Set 5 | camabatela
# Processing Record 21 of Set 5 | beihai
# Processing Record 22 of Set 5 | cidreira
# Processing Record 23 of Set 5 | constitucion
# Processing Record 24 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 5 | mwinilunga
# Processing Record 26 of Set 5 | swan river
# Processing Record 27 of Set 5 | mehamn
# Processing Record 28 of Set 5 | santa maria
# Processing Record 29 of Set 5 | noumea
# Processing Record 30 of Set 5 | smolenka
# Processing Record 31 of Set 5 | nelson bay
# Processing Record 32 of Set 5 | saldanha
# Processing Record 33 of Set 5 | baltay
# Processing Record 34 of Set 5 | buraydah
# Processing Record 35 of Set 5 | cabedelo
# Processing Record 36 of Set 5 | iquique
# Processing Record 37 of Set 5 | samarai
# Processing Record 38 of Set 5 | talaya
# Processing Record 39 of Set 5 | kem
# Processing Record 40 of Set 5 | kandi
# Processing Record 41 of Set 5 | matara
# Processing Record 42 of Set 5 | indian harbour beach
# Processing Record 43 of Set 5 | talnakh
# Processing Record 44 of Set 5 | shaoyang
# Processing Record 45 of Set 5 | hambantota
# Processing Record 46 of Set 5 | umm lajj
# Processing Record 47 of Set 5 | ozu
# Processing Record 48 of Set 5 | vardo
# Processing Record 49 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 50 of Set 5 | coalcoman
# City not found. Skipping...
# Processing Record 1 of Set 6 | mazamari
# Processing Record 2 of Set 6 | husavik
# Processing Record 3 of Set 6 | mill valley
# Processing Record 4 of Set 6 | geraldton
# Processing Record 5 of Set 6 | cairns
# Processing Record 6 of Set 6 | huarmey
# Processing Record 7 of Set 6 | synya
# Processing Record 8 of Set 6 | hailar
# Processing Record 9 of Set 6 | khor
# Processing Record 10 of Set 6 | yeppoon
# Processing Record 11 of Set 6 | bambanglipuro
# Processing Record 12 of Set 6 | lasa
# Processing Record 13 of Set 6 | poum
# Processing Record 14 of Set 6 | brigantine
# Processing Record 15 of Set 6 | gainesville
# Processing Record 16 of Set 6 | brae
# Processing Record 17 of Set 6 | santiago del estero
# Processing Record 18 of Set 6 | qarqin
# Processing Record 19 of Set 6 | pangkalanbuun
# Processing Record 20 of Set 6 | ust-ishim
# Processing Record 21 of Set 6 | tiksi
# Processing Record 22 of Set 6 | severnoye
# Processing Record 23 of Set 6 | yellowknife
# Processing Record 24 of Set 6 | yablochnyy
# Processing Record 25 of Set 6 | naryan-mar
# Processing Record 26 of Set 6 | shimoda
# Processing Record 27 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 6 | jeremie
# Processing Record 29 of Set 6 | ponta delgada
# Processing Record 30 of Set 6 | wanning
# Processing Record 31 of Set 6 | katsuura
# Processing Record 32 of Set 6 | isangel
# Processing Record 33 of Set 6 | kuusamo
# Processing Record 34 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 6 | general roca
# Processing Record 37 of Set 6 | ormara
# Processing Record 38 of Set 6 | salalah
# Processing Record 39 of Set 6 | pyaozerskiy
# Processing Record 40 of Set 6 | ginir
# Processing Record 41 of Set 6 | bonavista
# Processing Record 42 of Set 6 | pires do rio
# Processing Record 43 of Set 6 | chadiza
# Processing Record 44 of Set 6 | yelovo
# Processing Record 45 of Set 6 | antibes
# Processing Record 46 of Set 6 | churapcha
# Processing Record 47 of Set 6 | esperance
# Processing Record 48 of Set 6 | slantsy
# Processing Record 49 of Set 6 | gigmoto
# Processing Record 50 of Set 6 | nikolskoye
# Processing Record 1 of Set 7 | guia lopes da laguna
# Processing Record 2 of Set 7 | norman wells
# Processing Record 3 of Set 7 | goderich
# Processing Record 4 of Set 7 | moron
# Processing Record 5 of Set 7 | krasnyy yar
# Processing Record 6 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 7 | margate
# Processing Record 8 of Set 7 | saurimo
# Processing Record 9 of Set 7 | sungurlu
# Processing Record 10 of Set 7 | tateyama
# Processing Record 11 of Set 7 | cabo san lucas
# Processing Record 12 of Set 7 | frunze
# Processing Record 13 of Set 7 | petatlan
# Processing Record 14 of Set 7 | oriximina
# Processing Record 15 of Set 7 | lebu
# Processing Record 16 of Set 7 | xining
# Processing Record 17 of Set 7 | dasoguz
# Processing Record 18 of Set 7 | los llanos de aridane
# Processing Record 19 of Set 7 | camacha
# Processing Record 20 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 7 | bela
# Processing Record 22 of Set 7 | talavera
# Processing Record 23 of Set 7 | camacupa
# Processing Record 24 of Set 7 | numan
# Processing Record 25 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 26 of Set 7 | havelock
# Processing Record 27 of Set 7 | kita
# Processing Record 28 of Set 7 | port elizabeth
# Processing Record 29 of Set 7 | ostrovnoy
# Processing Record 30 of Set 7 | lorengau
# Processing Record 31 of Set 7 | iqaluit
# Processing Record 32 of Set 7 | naze
# Processing Record 33 of Set 7 | batagay-alyta
# Processing Record 34 of Set 7 | neyshabur
# Processing Record 35 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 7 | gobabis
# Processing Record 37 of Set 7 | grand gaube
# Processing Record 38 of Set 7 | sibolga
# Processing Record 39 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 40 of Set 7 | havoysund
# Processing Record 41 of Set 7 | narasannapeta
# Processing Record 42 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 7 | aguimes
# Processing Record 44 of Set 7 | maldonado
# Processing Record 45 of Set 7 | mudbidri
# Processing Record 46 of Set 7 | green river
# Processing Record 47 of Set 7 | grenada
# Processing Record 48 of Set 7 | pacific grove
# Processing Record 49 of Set 7 | pilao arcado
# City not found. Skipping...
# Processing Record 50 of Set 7 | dharchula
# Processing Record 1 of Set 8 | severo-kurilsk
# Processing Record 2 of Set 8 | tura
# Processing Record 3 of Set 8 | tuskegee
# Processing Record 4 of Set 8 | sterling
# Processing Record 5 of Set 8 | kumla
# Processing Record 6 of Set 8 | mitsamiouli
# Processing Record 7 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 8 | gravdal
# Processing Record 9 of Set 8 | ulaanbaatar
# Processing Record 10 of Set 8 | tingo maria
# Processing Record 11 of Set 8 | carutapera
# Processing Record 12 of Set 8 | gyanpur
# Processing Record 13 of Set 8 | chickasha
# Processing Record 14 of Set 8 | yarega
# Processing Record 15 of Set 8 | gat
# Processing Record 16 of Set 8 | high level
# Processing Record 17 of Set 8 | astoria
# Processing Record 18 of Set 8 | pevek
# Processing Record 19 of Set 8 | nyurba
# Processing Record 20 of Set 8 | ormond beach
# Processing Record 21 of Set 8 | troitsko-pechorsk
# Processing Record 22 of Set 8 | mandalgovi
# Processing Record 23 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 24 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 25 of Set 8 | waingapu
# Processing Record 26 of Set 8 | san francisco
# Processing Record 27 of Set 8 | kirakira
# Processing Record 28 of Set 8 | ranong
# Processing Record 29 of Set 8 | okha
# Processing Record 30 of Set 8 | caluquembe
# Processing Record 31 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 8 | paamiut
# Processing Record 33 of Set 8 | toora-khem
# Processing Record 34 of Set 8 | inuvik
# Processing Record 35 of Set 8 | tuktoyaktuk
# Processing Record 36 of Set 8 | port lincoln
# Processing Record 37 of Set 8 | saint-francois
# Processing Record 38 of Set 8 | nampula
# Processing Record 39 of Set 8 | touros
# Processing Record 40 of Set 8 | xinqing
# Processing Record 41 of Set 8 | sao joao do paraiso
# Processing Record 42 of Set 8 | oktyabrskoye
# Processing Record 43 of Set 8 | te anau
# Processing Record 44 of Set 8 | saskylakh
# Processing Record 45 of Set 8 | banda aceh
# Processing Record 46 of Set 8 | maarianhamina
# Processing Record 47 of Set 8 | zhigalovo
# Processing Record 48 of Set 8 | gurupi
# Processing Record 49 of Set 8 | nishihara
# Processing Record 50 of Set 8 | victor harbor
# Processing Record 1 of Set 9 | zhanakorgan
# Processing Record 2 of Set 9 | surgut
# Processing Record 3 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 4 of Set 9 | lawton
# Processing Record 5 of Set 9 | naberera
# Processing Record 6 of Set 9 | danville
# Processing Record 7 of Set 9 | kismayo
# Processing Record 8 of Set 9 | lahij
# Processing Record 9 of Set 9 | egvekinot
# Processing Record 10 of Set 9 | sorong
# Processing Record 11 of Set 9 | dauriya
# Processing Record 12 of Set 9 | verkhnyaya inta
# Processing Record 13 of Set 9 | nalut
# Processing Record 14 of Set 9 | tricase
# Processing Record 15 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 9 | yialos
# City not found. Skipping...
# Processing Record 17 of Set 9 | cardston
# Processing Record 18 of Set 9 | ulladulla
# Processing Record 19 of Set 9 | zonguldak
# Processing Record 20 of Set 9 | menongue
# Processing Record 21 of Set 9 | tazovskiy
# Processing Record 22 of Set 9 | khatanga
# Processing Record 23 of Set 9 | larap
# Processing Record 24 of Set 9 | chute-aux-outardes
# Processing Record 25 of Set 9 | kilimatinde
# Processing Record 26 of Set 9 | corning
# Processing Record 27 of Set 9 | pangnirtung
# Processing Record 28 of Set 9 | mafinga
# Processing Record 29 of Set 9 | adrar
# Processing Record 30 of Set 9 | boende
# Processing Record 31 of Set 9 | tromso
# Processing Record 32 of Set 9 | puerto quijarro
# Processing Record 33 of Set 9 | altamira
# Processing Record 34 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 9 | mandera
# Processing Record 36 of Set 9 | odweyne
# Processing Record 37 of Set 9 | sabang
# Processing Record 38 of Set 9 | doaba
# Processing Record 39 of Set 9 | gornopravdinsk
# Processing Record 40 of Set 9 | betong
# Processing Record 41 of Set 9 | itoman
# Processing Record 42 of Set 9 | klerksdorp
# Processing Record 43 of Set 9 | chicama
# Processing Record 44 of Set 9 | cunha
# Processing Record 45 of Set 9 | smithers
# Processing Record 46 of Set 9 | agua dulce
# Processing Record 47 of Set 9 | batagay
# Processing Record 48 of Set 9 | alibog
# City not found. Skipping...
# Processing Record 49 of Set 9 | ancud
# Processing Record 50 of Set 9 | saint george
# Processing Record 1 of Set 10 | suntar
# Processing Record 2 of Set 10 | sao filipe
# Processing Record 3 of Set 10 | luangwa
# Processing Record 4 of Set 10 | amapa
# Processing Record 5 of Set 10 | laem sing
# Processing Record 6 of Set 10 | ust-nera
# Processing Record 7 of Set 10 | esil
# Processing Record 8 of Set 10 | stromness
# Processing Record 9 of Set 10 | demba
# Processing Record 10 of Set 10 | iberia
# Processing Record 11 of Set 10 | kinablangan
# Processing Record 12 of Set 10 | victoria
# Processing Record 13 of Set 10 | bismil
# Processing Record 14 of Set 10 | berezovyy
# Processing Record 15 of Set 10 | lethem
# Processing Record 16 of Set 10 | jinchang
# Processing Record 17 of Set 10 | gouyave
# Processing Record 18 of Set 10 | tempio pausania
# Processing Record 19 of Set 10 | kapuskasing
# Processing Record 20 of Set 10 | ryotsu
# Processing Record 21 of Set 10 | louny
# Processing Record 22 of Set 10 | konya
# Processing Record 23 of Set 10 | drovyanaya
# Processing Record 24 of Set 10 | vitoria do mearim
# Processing Record 25 of Set 10 | hami
# Processing Record 26 of Set 10 | staicele
# Processing Record 27 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 10 | yaypan
# Processing Record 29 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 10 | guadalupe y calvo
# Processing Record 31 of Set 10 | kununurra
# Processing Record 32 of Set 10 | poronaysk
# Processing Record 33 of Set 10 | vila velha
# Processing Record 34 of Set 10 | pundaguitan
# Processing Record 35 of Set 10 | kotelnich
# Processing Record 36 of Set 10 | kandrian
# Processing Record 37 of Set 10 | roald
# Processing Record 38 of Set 10 | shchigry
# Processing Record 39 of Set 10 | yerbogachen
# Processing Record 40 of Set 10 | mendeleyevsk
# Processing Record 41 of Set 10 | gogrial
# Processing Record 42 of Set 10 | terrasini
# Processing Record 43 of Set 10 | faanui
# Processing Record 44 of Set 10 | longhua
# Processing Record 45 of Set 10 | harigue
# City not found. Skipping...
# Processing Record 46 of Set 10 | bedesa
# Processing Record 47 of Set 10 | gasa
# Processing Record 48 of Set 10 | bud
# Processing Record 49 of Set 10 | wewak
# Processing Record 50 of Set 10 | kalmunai
# Processing Record 1 of Set 11 | teya
# Processing Record 2 of Set 11 | srednekolymsk
# Processing Record 3 of Set 11 | sorland
# Processing Record 4 of Set 11 | alcala de henares
# Processing Record 5 of Set 11 | port-gentil
# Processing Record 6 of Set 11 | sharjah
# Processing Record 7 of Set 11 | nemuro
# Processing Record 8 of Set 11 | noshiro
# Processing Record 9 of Set 11 | bathsheba
# Processing Record 10 of Set 11 | whitehorse
# Processing Record 11 of Set 11 | vila franca do campo
# Processing Record 12 of Set 11 | lashio
# Processing Record 13 of Set 11 | codrington
# Processing Record 14 of Set 11 | bayan
# Processing Record 15 of Set 11 | cockburn town
# Processing Record 16 of Set 11 | atikokan
# Processing Record 17 of Set 11 | kokopo
# Processing Record 18 of Set 11 | tasiilaq
# Processing Record 19 of Set 11 | bhuj
# Processing Record 20 of Set 11 | ayagoz
# Processing Record 21 of Set 11 | apeldoorn
# Processing Record 22 of Set 11 | oranjestad
# Processing Record 23 of Set 11 | kashi
# Processing Record 24 of Set 11 | oudtshoorn
# Processing Record 25 of Set 11 | faya
# Processing Record 26 of Set 11 | mori
# Processing Record 27 of Set 11 | otane
# Processing Record 28 of Set 11 | axim
# Processing Record 29 of Set 11 | meulaboh
# Processing Record 30 of Set 11 | tabuk
# Processing Record 31 of Set 11 | badou
# Processing Record 32 of Set 11 | rurrenabaque
# Processing Record 33 of Set 11 | arawa
# Processing Record 34 of Set 11 | niksar
# Processing Record 35 of Set 11 | prince rupert
# Processing Record 36 of Set 11 | koudougou
# Processing Record 37 of Set 11 | buala
# Processing Record 38 of Set 11 | west wendover
# Processing Record 39 of Set 11 | berezovka
# Processing Record 40 of Set 11 | corralillo
# Processing Record 41 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 42 of Set 11 | cedar city
# Processing Record 43 of Set 11 | aykhal
# Processing Record 44 of Set 11 | karatau
# Processing Record 45 of Set 11 | limoux
# Processing Record 46 of Set 11 | richards bay
# Processing Record 47 of Set 11 | sisimiut
# Processing Record 48 of Set 11 | reitz
# Processing Record 49 of Set 11 | christchurch
# Processing Record 50 of Set 11 | chapais
# Processing Record 1 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 12 | sampit
# Processing Record 3 of Set 12 | zunyi
# Processing Record 4 of Set 12 | dwarka
# Processing Record 5 of Set 12 | kijini
# Processing Record 6 of Set 12 | angoche
# Processing Record 7 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 8 of Set 12 | san carlos de bariloche
# Processing Record 9 of Set 12 | urubicha
# Processing Record 10 of Set 12 | belfast
# Processing Record 11 of Set 12 | cravo norte
# Processing Record 12 of Set 12 | tiznit
# Processing Record 13 of Set 12 | yenagoa
# Processing Record 14 of Set 12 | rocha
# Processing Record 15 of Set 12 | salacgriva
# Processing Record 16 of Set 12 | zhezkazgan
# Processing Record 17 of Set 12 | praia da vitoria
# Processing Record 18 of Set 12 | chiang rai
# Processing Record 19 of Set 12 | zhoucheng
# Processing Record 20 of Set 12 | muzhi
# Processing Record 21 of Set 12 | kouango
# Processing Record 22 of Set 12 | ponoka
# Processing Record 23 of Set 12 | thunder bay
# Processing Record 24 of Set 12 | keti bandar
# Processing Record 25 of Set 12 | muisne
# Processing Record 26 of Set 12 | khilok
# Processing Record 27 of Set 12 | kahului
# Processing Record 28 of Set 12 | ranau
# Processing Record 29 of Set 12 | ghanzi
# Processing Record 30 of Set 12 | osakarovka
# Processing Record 31 of Set 12 | catamarca
# Processing Record 32 of Set 12 | necochea
# Processing Record 33 of Set 12 | san quintin
# Processing Record 34 of Set 12 | kanpur
# Processing Record 35 of Set 12 | emerald
# Processing Record 36 of Set 12 | qiongshan
# Processing Record 37 of Set 12 | loralai
# Processing Record 38 of Set 12 | ciudad bolivar
# Processing Record 39 of Set 12 | anamur
# Processing Record 40 of Set 12 | tecoanapa
# Processing Record 41 of Set 12 | burica
# City not found. Skipping...
# Processing Record 42 of Set 12 | kearney
# Processing Record 43 of Set 12 | skjervoy
# Processing Record 44 of Set 12 | ketchikan
# Processing Record 45 of Set 12 | trelew
# Processing Record 46 of Set 12 | khani
# Processing Record 47 of Set 12 | homer
# Processing Record 48 of Set 12 | hilton head island
# Processing Record 49 of Set 12 | deputatskiy
# Processing Record 50 of Set 12 | una
# Processing Record 1 of Set 13 | salta
# Processing Record 2 of Set 13 | piterka
# Processing Record 3 of Set 13 | tecpan
# Processing Record 4 of Set 13 | atasu
# Processing Record 5 of Set 13 | seoul
# Processing Record 6 of Set 13 | khash
# Processing Record 7 of Set 13 | tambo
# Processing Record 8 of Set 13 | ambulu
# Processing Record 9 of Set 13 | salinopolis
# Processing Record 10 of Set 13 | kosonsoy
# Processing Record 11 of Set 13 | kanel
# Processing Record 12 of Set 13 | olenegorsk
# Processing Record 13 of Set 13 | moose factory
# Processing Record 14 of Set 13 | police
# Processing Record 15 of Set 13 | rancho palos verdes
# Processing Record 16 of Set 13 | sao felix do xingu
# Processing Record 17 of Set 13 | challans
# Processing Record 18 of Set 13 | colares
# Processing Record 19 of Set 13 | nivala
# Processing Record 20 of Set 13 | katangli
# Processing Record 21 of Set 13 | valdepenas
# Processing Record 22 of Set 13 | kabo
# Processing Record 23 of Set 13 | komsomolets
# Processing Record 24 of Set 13 | kuching
# Processing Record 25 of Set 13 | batemans bay
# Processing Record 26 of Set 13 | cotonou
# Processing Record 27 of Set 13 | shellbrook
# Processing Record 28 of Set 13 | anjozorobe
# Processing Record 29 of Set 13 | krasnoselkup
# Processing Record 30 of Set 13 | sumbe
# Processing Record 31 of Set 13 | ostersund
# Processing Record 32 of Set 13 | lavumisa
# Processing Record 33 of Set 13 | yele
# Processing Record 34 of Set 13 | togur
# Processing Record 35 of Set 13 | thinadhoo
# Processing Record 36 of Set 13 | zwedru
# Processing Record 37 of Set 13 | winnemucca
# Processing Record 38 of Set 13 | quatre cocos
# Processing Record 39 of Set 13 | santa
# Processing Record 40 of Set 13 | barcelos
# Processing Record 41 of Set 13 | chumphon
# Processing Record 42 of Set 13 | point fortin
# Processing Record 43 of Set 13 | polyarnyy
# Processing Record 44 of Set 13 | shihezi
# Processing Record 45 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 13 | comodoro rivadavia
# Processing Record 47 of Set 13 | roebourne
# Processing Record 48 of Set 13 | manjacaze
# Processing Record 49 of Set 13 | sinazongwe
# Processing Record 50 of Set 13 | harsin
# Processing Record 1 of Set 14 | birin
# Processing Record 2 of Set 14 | karwar
# Processing Record 3 of Set 14 | valparaiso
# Processing Record 4 of Set 14 | lakes entrance
# Processing Record 5 of Set 14 | zyryanskoye
# Processing Record 6 of Set 14 | abeche
# Processing Record 7 of Set 14 | atmakur
# Processing Record 8 of Set 14 | qasigiannguit
# Processing Record 9 of Set 14 | kyzyl-suu
# Processing Record 10 of Set 14 | estelle
# Processing Record 11 of Set 14 | soto
# Processing Record 12 of Set 14 | taoudenni
# Processing Record 13 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 14 | iwanai
# Processing Record 15 of Set 14 | misratah
# Processing Record 16 of Set 14 | emba
# Processing Record 17 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 14 | talen
# Processing Record 19 of Set 14 | caravelas
# Processing Record 20 of Set 14 | santa ana
# Processing Record 21 of Set 14 | stokmarknes
# Processing Record 22 of Set 14 | ituporanga
# Processing Record 23 of Set 14 | sao joao da barra
# Processing Record 24 of Set 14 | nabire
# Processing Record 25 of Set 14 | kholodnyy
# Processing Record 26 of Set 14 | kamaishi
# Processing Record 27 of Set 14 | lensk
# Processing Record 28 of Set 14 | kushva
# Processing Record 29 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 30 of Set 14 | port hedland
# Processing Record 31 of Set 14 | san lazaro
# Processing Record 32 of Set 14 | sola
# Processing Record 33 of Set 14 | nieves
# Processing Record 34 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 35 of Set 14 | lugovoy
# Processing Record 36 of Set 14 | urusha
# Processing Record 37 of Set 14 | uthal
# Processing Record 38 of Set 14 | kieta
# Processing Record 39 of Set 14 | padang
# Processing Record 40 of Set 14 | santa vitoria do palmar
# Processing Record 41 of Set 14 | eyl
# Processing Record 42 of Set 14 | sotnikovo
# Processing Record 43 of Set 14 | lucea
# Processing Record 44 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 14 | belmonte
# Processing Record 46 of Set 14 | baruun-urt
# Processing Record 47 of Set 14 | saint-joseph
# Processing Record 48 of Set 14 | sompeta
# Processing Record 49 of Set 14 | kuala terengganu
# Processing Record 50 of Set 14 | taperoa
# Processing Record 1 of Set 15 | lavara
# Processing Record 2 of Set 15 | tocopilla
# Processing Record 3 of Set 15 | keetmanshoop
# Processing Record 4 of Set 15 | nakapiripirit
# Processing Record 5 of Set 15 | nautla
# Processing Record 6 of Set 15 | kabare
# Processing Record 7 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 8 of Set 15 | tuim
# Processing Record 9 of Set 15 | cayenne
# Processing Record 10 of Set 15 | waddan
# Processing Record 11 of Set 15 | fare
# Processing Record 12 of Set 15 | ankazoabo
# Processing Record 13 of Set 15 | bousso
# Processing Record 14 of Set 15 | challakere
# Processing Record 15 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 16 of Set 15 | broome
# Processing Record 17 of Set 15 | blagoyevo
# Processing Record 18 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 19 of Set 15 | gondanglegi
# Processing Record 20 of Set 15 | tumwater
# Processing Record 21 of Set 15 | kaele
# Processing Record 22 of Set 15 | dovolnoye
# Processing Record 23 of Set 15 | ortigueira
# Processing Record 24 of Set 15 | la ronge
# Processing Record 25 of Set 15 | nizhniy kuranakh
# Processing Record 26 of Set 15 | hearst
# Processing Record 27 of Set 15 | muli
# Processing Record 28 of Set 15 | muroto
# Processing Record 29 of Set 15 | shushtar
# Processing Record 30 of Set 15 | fairbanks
# Processing Record 31 of Set 15 | sao lourenco do sul
# Processing Record 32 of Set 15 | kot kapura
# Processing Record 33 of Set 15 | norden
# Processing Record 34 of Set 15 | bonthe
# Processing Record 35 of Set 15 | mazatlan
# Processing Record 36 of Set 15 | pochutla
# Processing Record 37 of Set 15 | tiarei
# Processing Record 38 of Set 15 | naron
# Processing Record 39 of Set 15 | dipkarpaz
# City not found. Skipping...
# Processing Record 40 of Set 15 | marystown
# Processing Record 41 of Set 15 | rivera
# Processing Record 42 of Set 15 | san felipe
# Processing Record 43 of Set 15 | laguna
# Processing Record 44 of Set 15 | saryozek
# Processing Record 45 of Set 15 | vieux fort
# Processing Record 46 of Set 15 | praya
# Processing Record 47 of Set 15 | dod ballapur
# Processing Record 48 of Set 15 | arlit
# Processing Record 49 of Set 15 | kalachinsk
# Processing Record 50 of Set 15 | taltal
# Processing Record 1 of Set 16 | makakilo city
# Processing Record 2 of Set 16 | opuwo
# Processing Record 3 of Set 16 | leninskoye
# Processing Record 4 of Set 16 | begoro
# Processing Record 5 of Set 16 | svetlogorsk
# Processing Record 6 of Set 16 | barra
# Processing Record 7 of Set 16 | cheuskiny
# City not found. Skipping...
# Processing Record 8 of Set 16 | plettenberg bay
# Processing Record 9 of Set 16 | dauphin
# Processing Record 10 of Set 16 | alingsas
# Processing Record 11 of Set 16 | mato verde
# Processing Record 12 of Set 16 | college
# Processing Record 13 of Set 16 | itarema
# Processing Record 14 of Set 16 | kichera
# Processing Record 15 of Set 16 | koungou
# Processing Record 16 of Set 16 | tuyen quang
# Processing Record 17 of Set 16 | ishinomaki
# Processing Record 18 of Set 16 | flin flon
# Processing Record 19 of Set 16 | tomatlan
# Processing Record 20 of Set 16 | urumqi
# Processing Record 21 of Set 16 | nchelenge
# Processing Record 22 of Set 16 | jiexiu
# Processing Record 23 of Set 16 | sept-iles
# Processing Record 24 of Set 16 | piacabucu
# Processing Record 25 of Set 16 | andenes
# Processing Record 26 of Set 16 | kiunga
# Processing Record 27 of Set 16 | vilyuysk
# Processing Record 28 of Set 16 | debre tabor
# Processing Record 29 of Set 16 | ambilobe
# Processing Record 30 of Set 16 | portland
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0  Beringovskiy  63.0500  179.3167     overcast clouds     43.70        66
# 1        Albany  42.6001  -73.9662       moderate rain     65.95        94
# 2        Avarua -21.2078 -159.7750          light rain     73.45        94
# 3    Butaritari   3.0707  172.7902          light rain     81.00        81
# 4         Wabag  -5.4781  143.7021     overcast clouds     71.24        35
# 5        Atuona  -9.8000 -139.0333           clear sky     76.75        66
# 6  San Patricio  28.0170  -97.5169     overcast clouds     82.35        86
# 7    North Bend  43.4065 -124.2243           clear sky     84.24        75
# 8       Kewanee  41.2456  -89.9248    scattered clouds     71.47        87
# 9      Souillac -20.5167   57.5167    scattered clouds     70.18        78
#
#    Cloudiness  Wind Speed Country
# 0         100       15.12      RU
# 1         100        2.17      US
# 2         100       14.97      CK
# 3         100       17.65      KI
# 4         100        4.85      PG
# 5           0       20.65      PF
# 6         100        6.15      US
# 7           0       21.85      US
# 8          28        8.77      US
# 9          40       10.36      MU

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Beringovskiy      RU  63.0500  179.3167     43.70        66         100
# 1          Albany      US  42.6001  -73.9662     65.95        94         100
# 2          Avarua      CK -21.2078 -159.7750     73.45        94         100
# 3      Butaritari      KI   3.0707  172.7902     81.00        81         100
# 4           Wabag      PG  -5.4781  143.7021     71.24        35         100
# ..            ...     ...      ...       ...       ...       ...         ...
# 715        Kiunga      PG  -6.1219  141.2906     83.08        74         100
# 716      Vilyuysk      RU  63.7553  121.6247     46.06        89         100
# 717   Debre Tabor      ET  11.8500   38.0167     48.85        86           7
# 718      Ambilobe      MG -13.2000   49.0500     65.66        76           0
# 719      Portland      US  45.5234 -122.6762     82.71        42          20
#
#      Wind Speed Current Description
# 0         15.12     overcast clouds
# 1          2.17       moderate rain
# 2         14.97          light rain
# 3         17.65          light rain
# 4          4.85     overcast clouds
# ..          ...                 ...
# 715        3.71     overcast clouds
# 716        6.64     overcast clouds
# 717        2.19           clear sky
# 718        3.47           clear sky
# 719       13.80          few clouds
#
# [720 rows x 9 columns]

# %%
from pathlib import Path

# %%
import os

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
